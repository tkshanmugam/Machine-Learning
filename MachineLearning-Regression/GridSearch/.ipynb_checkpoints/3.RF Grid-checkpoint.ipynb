# %%
#importing the Libraies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Reading the Dataset
dataset = pd.read_csv('insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
indep=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dep=dataset['charges']

# %%
#split into training set and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(indep, dep, test_size = 1/3, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
#from sklearn.tree import DecisionTreeRegressor
param_grid = {'criterion':['poisson', 'friedman_mse', 'absolute_error', 'squared_error'],'max_features': ['auto','sqrt','log2'],'n_estimators':[10,100]}
grid = GridSearchCV(RandomForestRegressor(), param_grid, refit = True, verbose= 3,n_jobs=-1)
# fitting the model for grid search
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['poisson', 'friedman_mse',
#                                        'absolute_error', 'squared_error'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
# print best parameter after tuning
#print(grid.best_params_)
re=grid.cv_results_
#print(re)
grid_predictions = grid.predict(X_test)
# print classification report
from sklearn.metrics import r2_score
r_score=r2_score(y_test,grid_predictions)
print("The R_score value for best parameter {}:".format(grid.best_params_),r_score)
# Out:
# The R_score value for best parameter {'criterion': 'absolute_error', 'max_features': 'log2', 'n_estimators': 100}: 0.8727031574229639

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.073196      0.002033         0.003850        0.000700
# 1        0.611054      0.010175         0.020149        0.000688
# 2        0.049220      0.002239         0.003155        0.000427
# 3        0.473836      0.010245         0.019610        0.000914
# 4        0.052425      0.002361         0.003514        0.000460
# 5        0.481924      0.004166         0.021375        0.002370
# 6        0.062349      0.001759         0.003047        0.000427
# 7        0.552773      0.004030         0.019629        0.001142
# 8        0.047589      0.002951         0.002840        0.000378
# 9        0.436975      0.001835         0.018883        0.001212
# 10       0.044229      0.001183         0.002995        0.000544
# 11       0.431990      0.010010         0.019034        0.000961
# 12       0.174932      0.003052         0.003219        0.000289
# 13       1.708387      0.019107         0.017815        0.000740
# 14       0.107801      0.001388         0.002999        0.000044
# 15       1.055033      0.017438         0.017637        0.000486
# 16       0.107151      0.002389         0.002813        0.000406
# 17       1.067254      0.019518         0.017961        0.000982
# 18       0.059492      0.002117         0.003032        0.000059
# 19       0.539558      0.006269         0.018063        0.001113
# 20       0.046305      0.002592         0.003033        0.000043
# 21       0.415965      0.010319         0.017436        0.000513
# 22       0.044914      0.000938         0.002802        0.000400
# 23       0.398790      0.027853         0.014643        0.002210
#
#    param_criterion param_max_features param_n_estimators  \
# 0          poisson               auto                 10
# 1          poisson               auto                100
# 2          poisson               sqrt                 10
# 3          poisson               sqrt                100
# 4          poisson               log2                 10
# 5          poisson               log2                100
# 6     friedman_mse               auto                 10
# 7     friedman_mse               auto                100
# 8     friedman_mse               sqrt                 10
# 9     friedman_mse               sqrt                100
# 10    friedman_mse               log2                 10
# 11    friedman_mse               log2                100
# 12  absolute_error               auto                 10
# 13  absolute_error               auto                100
# 14  absolute_error               sqrt                 10
# 15  absolute_error               sqrt                100
# 16  absolute_error               log2                 10
# 17  absolute_error               log2                100
# 18   squared_error               auto                 10
# 19   squared_error               auto                100
# 20   squared_error               sqrt                 10
# 21   squared_error               sqrt                100
# 22   squared_error               log2                 10
# 23   squared_error               log2                100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'poisson', 'max_features': 'auto...           0.789704
# 1   {'criterion': 'poisson', 'max_features': 'auto...           0.808622
# 2   {'criterion': 'poisson', 'max_features': 'sqrt...           0.795771
# 3   {'criterion': 'poisson', 'max_features': 'sqrt...           0.811933
# 4   {'criterion': 'poisson', 'max_features': 'log2...           0.775416
# 5   {'criterion': 'poisson', 'max_features': 'log2...           0.805807
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.785605
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.804518
# 8   {'criterion': 'friedman_mse', 'max_features': ...           0.763579
# 9   {'criterion': 'friedman_mse', 'max_features': ...           0.806139
# 10  {'criterion': 'friedman_mse', 'max_features': ...           0.773023
# 11  {'criterion': 'friedman_mse', 'max_features': ...           0.808251
# 12  {'criterion': 'absolute_error', 'max_features'...           0.768471
# 13  {'criterion': 'absolute_error', 'max_features'...           0.785863
# 14  {'criterion': 'absolute_error', 'max_features'...           0.776957
# 15  {'criterion': 'absolute_error', 'max_features'...           0.798043
# 16  {'criterion': 'absolute_error', 'max_features'...           0.781130
# 17  {'criterion': 'absolute_error', 'max_features'...           0.808628
# 18  {'criterion': 'squared_error', 'max_features':...           0.794434
# 19  {'criterion': 'squared_error', 'max_features':...           0.804694
# 20  {'criterion': 'squared_error', 'max_features':...           0.786415
# 21  {'criterion': 'squared_error', 'max_features':...           0.809286
# 22  {'criterion': 'squared_error', 'max_features':...           0.771401
# 23  {'criterion': 'squared_error', 'max_features':...           0.808875
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.742131           0.818145           0.747097
# 1            0.751288           0.832469           0.805168
# 2            0.762516           0.820198           0.801848
# 3            0.771380           0.832992           0.830941
# 4            0.750312           0.786503           0.782478
# 5            0.771099           0.835050           0.827526
# 6            0.742322           0.836293           0.791250
# 7            0.739744           0.834466           0.804148
# 8            0.751645           0.819425           0.799967
# 9            0.773228           0.834108           0.829078
# 10           0.722224           0.817366           0.823479
# 11           0.773401           0.834713           0.831856
# 12           0.755436           0.797341           0.766860
# 13           0.770844           0.816402           0.804980
# 14           0.714267           0.821373           0.820376
# 15           0.772550           0.840934           0.829800
# 16           0.773778           0.814518           0.824590
# 17           0.772270           0.842810           0.829025
# 18           0.743765           0.801912           0.776427
# 19           0.756278           0.827532           0.803018
# 20           0.774575           0.808580           0.826994
# 21           0.763581           0.840998           0.828781
# 22           0.760464           0.794308           0.799928
# 23           0.763912           0.830174           0.832464
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.749476         0.769310        0.029753               22
# 1            0.763024         0.792114        0.030280               10
# 2            0.754218         0.786910        0.024794               13
# 3            0.763018         0.802053        0.029509                3
# 4            0.726554         0.764252        0.022660               24
# 5            0.756423         0.799181        0.030825                7
# 6            0.760939         0.783282        0.031799               16
# 7            0.760041         0.788584        0.034063               12
# 8            0.763786         0.779680        0.025648               17
# 9            0.768516         0.802214        0.027313                2
# 10           0.747015         0.776622        0.039254               19
# 11           0.757357         0.801116        0.031008                4
# 12           0.756225         0.768866        0.015200               23
# 13           0.755279         0.786674        0.022162               14
# 14           0.752468         0.777088        0.040958               18
# 15           0.755673         0.799400        0.032509                6
# 16           0.730979         0.784999        0.033160               15
# 17           0.763013         0.803149        0.031103                1
# 18           0.752083         0.773724        0.022789               20
# 19           0.765795         0.791463        0.026482               11
# 20           0.764293         0.792171        0.022812                9
# 21           0.759141         0.800358        0.033438                5
# 22           0.735856         0.772391        0.023310               21
# 23           0.756957         0.798476        0.032207                8

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age:43
# BMI:42
# Children:1
# Sex Male 0 or 1:6
# Smoker Yes 0 or 1:1

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
#change the paramter,play with it.
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[46642.0736243]
