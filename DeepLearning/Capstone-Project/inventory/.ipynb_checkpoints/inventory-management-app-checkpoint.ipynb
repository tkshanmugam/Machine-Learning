# %%
# !pip3 install imgaug
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting imgaug
#   Downloading imgaug-0.4.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from imgaug) (1.16.0)
# Requirement already satisfied: numpy>=1.15 in c:\programdata\anaconda3\lib\site-packages (from imgaug) (1.26.4)
# Requirement already satisfied: scipy in c:\programdata\anaconda3\lib\site-packages (from imgaug) (1.11.4)
# Requirement already satisfied: Pillow in c:\programdata\anaconda3\lib\site-packages (from imgaug) (10.2.0)
# Requirement already satisfied: matplotlib in c:\programdata\anaconda3\lib\site-packages (from imgaug) (3.8.0)
# Requirement already satisfied: scikit-image>=0.14.2 in c:\programdata\anaconda3\lib\site-packages (from imgaug) (0.22.0)
# Requirement already satisfied: opencv-python in c:\users\zuyyu\appdata\roaming\python\python311\site-packages (from imgaug) (4.10.0.84)
# Requirement already satisfied: imageio in c:\programdata\anaconda3\lib\site-packages (from imgaug) (2.33.1)
# Collecting Shapely (from imgaug)
#   Downloading shapely-2.0.4-cp311-cp311-win_amd64.whl.metadata (7.2 kB)
# Requirement already satisfied: networkx>=2.8 in c:\programdata\anaconda3\lib\site-packages (from scikit-image>=0.14.2->imgaug) (3.1)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\programdata\anaconda3\lib\site-packages (from scikit-image>=0.14.2->imgaug) (2023.4.12)
# Requirement already satisfied: packaging>=21 in c:\programdata\anaconda3\lib\site-packages (from scikit-image>=0.14.2->imgaug) (23.1)
# Requirement already satisfied: lazy_loader>=0.3 in c:\programdata\anaconda3\lib\site-packages (from scikit-image>=0.14.2->imgaug) (0.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->imgaug) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->imgaug) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->imgaug) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->imgaug) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->imgaug) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->imgaug) (2.8.2)
# Downloading imgaug-0.4.0-py2.py3-none-any.whl (948 kB)
#    ---------------------------------------- 0.0/948.0 kB ? eta -:--:--
#    ---------------------------------------- 10.2/948.0 kB ? eta -:--:--
#    - ------------------------------------- 30.7/948.0 kB 435.7 kB/s eta 0:00:03
#    --- ----------------------------------- 92.2/948.0 kB 871.5 kB/s eta 0:00:01
#    -------- ------------------------------- 204.8/948.0 kB 1.4 MB/s eta 0:00:01
#    --------------- ------------------------ 368.6/948.0 kB 2.1 MB/s eta 0:00:01
#    --------------- ------------------------ 368.6/948.0 kB 2.1 MB/s eta 0:00:01
#    -------------------------------------- - 901.1/948.0 kB 3.6 MB/s eta 0:00:01
#    ---------------------------------------- 948.0/948.0 kB 3.0 MB/s eta 0:00:00
# Downloading shapely-2.0.4-cp311-cp311-win_amd64.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB 8.9 MB/s eta 0:00:01
#    ---------------- ----------------------- 0.6/1.4 MB 7.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 0.8/1.4 MB 6.7 MB/s eta 0:00:01
#    ------------------------------- -------- 1.1/1.4 MB 6.0 MB/s eta 0:00:01
#    ---------------------------------------  1.4/1.4 MB 6.5 MB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 5.7 MB/s eta 0:00:00
# Installing collected packages: Shapely, imgaug
# Successfully installed Shapely-2.0.4 imgaug-0.4.0

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os, random, cv2, pickle, json, itertools
import imgaug.augmenters as iaa
import imgaug.imgaug
import tensorflow as tf

from IPython.display import SVG
from tensorflow.keras.utils import plot_model, model_to_dot
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from collections import Counter
from sklearn.utils import class_weight
from tqdm import tqdm
from sklearn.preprocessing import LabelBinarizer

from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint, Callback, EarlyStopping
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import (Add, Input, Conv2D, Dropout, Activation, BatchNormalization, MaxPool2D, ZeroPadding2D, AveragePooling2D, Flatten, Dense)
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint, Callback, EarlyStopping
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.initializers import *

# %%
def show_final_history(history):
    
    plt.style.use("ggplot")
    fig, ax = plt.subplots(1,2,figsize=(15,5))
    ax[0].set_title('Loss')
    ax[1].set_title('Accuracy')
    ax[0].plot(history.history['loss'],label='Train Loss')
    ax[0].plot(history.history['val_loss'],label='Validation Loss')
    ax[1].plot(history.history['accuracy'],label='Train Accuracy')
    ax[1].plot(history.history['val_accuracy'],label='Validation Accuracy')
    
    ax[0].legend(loc='upper right')
    ax[1].legend(loc='lower right')
    plt.show();
    pass

# %%
datasets = ['data_week1/images']

class_names = ["MILK","NUTS","OIL","SODA","TEA"]

class_name_labels = {class_name:i for i,class_name in enumerate(class_names)}

num_classes = len(class_names)
class_name_labels
# Out:
# {'MILK': 0, 'NUTS': 1, 'OIL': 2, 'SODA': 3, 'TEA': 4}

# %%
def load_data():
    images, labels = [], []
    
    for dataset in datasets:
        
        for folder in os.listdir(dataset):
            label = class_name_labels[folder]
            
            for file in tqdm(os.listdir(os.path.join(dataset,folder))):
                
                img_path = os.path.join(dataset,folder,file)
                
                img = cv2.imread(img_path)
                img = cv2.resize(img, (96,96))
                
                images.append(img)
                labels.append(label)
                pass
            pass
        
        images = np.array(images,dtype=np.float32)/255.0
        labels = np.array(labels,dtype=np.float32)
        pass
    
    return (images, labels)
    pass

# %%
(images, labels) = load_data()
images.shape, labels.shape
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 162/162 [00:00<00:00, 261.74it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 168/168 [00:00<00:00, 300.47it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 143/143 [00:00<00:00, 334.35it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 177/177 [00:00<00:00, 288.37it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 283/283 [00:00<00:00, 290.24it/s]
# ((933, 96, 96, 3), (933,))

# %%
n_labels = labels.shape[0]

_, count = np.unique(labels, return_counts=True)

df = pd.DataFrame(data = count)
df['Class Label'] = class_names
df.columns = ['Count','Class-Label']
df.set_index('Class-Label',inplace=True)
df
# Out:
#              Count
# Class-Label
# MILK           162
# NUTS           168
# OIL            143
# SODA           177
# TEA            283

# %%
def augment_add(images, seq, labels):
    
    augmented_images, augmented_labels = [],[]
    for idx,img in tqdm(enumerate(images)):
        
        if labels[idx] == 1:
            image_aug_1 = seq.augment_image(image=img)
            image_aug_2 = seq.augment_image(image=img)
            augmented_images.append(image_aug_1)
            augmented_images.append(image_aug_2)
            augmented_labels.append(labels[idx])
            augmented_labels.append(labels[idx])
        pass
    
    augmented_images = np.array(augmented_images, dtype=np.float32)
    augmented_labels = np.array(augmented_labels, dtype=np.float32)
    
    return (augmented_images, augmented_labels)
    pass

# %%
seq = iaa.Sequential([
    iaa.Fliplr(0.5),
    iaa.Crop(percent=(0,0.1)),
    iaa.LinearContrast((0.75,1.5)),
    iaa.Multiply((0.8,1.2), per_channel=0.2),
    iaa.Affine(
        scale={'x':(0.8,1.2), "y":(0.8,1.2)},
        translate_percent={"x":(-0.2,0.2),"y":(-0.2,0.2)},
        rotate=(-25,25),
        shear=(-8,8)
    )
], random_order=True)

# %%
(aug_images, aug_labels) = augment_add(images, seq, labels)
images = np.concatenate([images, aug_images])
labels = np.concatenate([labels, aug_labels])
# Out:
# 933it [00:00, 1055.00it/s]

# %%
images.shape, labels.shape
# Out:
# ((1269, 96, 96, 3), (1269,))

# %%
labels = to_categorical(labels)

# %%
np.random.seed(42)
np.random.shuffle(images)

np.random.seed(42)
np.random.shuffle(labels)

# %%
total_count = len(images)
total_count

train = int(0.7*total_count)
val = int(0.2*total_count)
test = int(0.1*total_count)

train_images, train_labels = images[:train], labels[:train]
val_images, val_labels = images[train:(val+train)], labels[train:(val+train)]
test_images, test_labels = images[-test:], labels[-test:]

train_images.shape, val_images.shape, test_images.shape
# Out:
# ((888, 96, 96, 3), (253, 96, 96, 3), (126, 96, 96, 3))

# %%
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
model = Sequential([
    Input(shape=(96, 96, 3)),
    
    # Block 1
    Conv2D(32, (3, 3), activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2, 2)),
    Dropout(0.3),
    
    # Block 2
    Conv2D(64, (3, 3), activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2, 2)),
    Dropout(0.3),
    
    # Block 3
    Conv2D(128, (3, 3), activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2, 2)),
    Dropout(0.4),
    
    # Block 4
    Conv2D(256, (3, 3), activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2, 2)),
    Dropout(0.3),
    
    # Block 5
    Conv2D(512, (3, 3), activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2, 2)),
    Dropout(0.3),
    
    # Flatten and fully connected layers
    Flatten(),
    Dense(256, activation='relu'),
    Dropout(0.5),
    Dense(5, activation='softmax')
])

# %%
checkpoint = ModelCheckpoint(
    './base_model.keras',
    monitor='val_accuracy',
    verbose=1,
    save_best_only=True,
    mode='max',
    save_weights_only=False
    #save_frequency=1
)
earlystop = EarlyStopping(
    monitor='val_loss',
    min_delta=0.001,
    patience=50,
    verbose=1,
    mode='auto'
)

opt = Adam(learning_rate=1e-3)

callbacks = [checkpoint,earlystop]

model.compile(optimizer=opt,loss='binary_crossentropy',metrics=['accuracy'])

# %%
epochs = 200
batch_size = 32

history = model.fit(train_images,train_labels,
                    batch_size=batch_size,
                   steps_per_epoch=len(train_images)//batch_size,
                   epochs=epochs,
                   verbose=1, 
                   validation_data=(val_images,val_labels),
                   validation_steps=len(val_images)//batch_size,
                   callbacks=callbacks
                   )
# Out:
# Epoch 1/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.2550 - loss: 0.7842
# Epoch 1: val_accuracy improved from -inf to 0.41964, saving model to ./base_model.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 14s 271ms/step - accuracy: 0.2540 - loss: 0.7792 - val_accuracy: 0.4196 - val_loss: 0.6599
# Epoch 2/200
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 5s 200ms/step - accuracy: 0.2500 - loss: 0.5721
# Epoch 2: val_accuracy improved from 0.41964 to 0.44828, saving model to ./base_model.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.2500 - loss: 0.5721 - val_accuracy: 0.4483 - val_loss: 0.6596
# Epoch 3/200
# C:\ProgramData\anaconda3\Lib\contextlib.py:158: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - accuracy: 0.3177 - loss: 0.5229
# Epoch 3: val_accuracy did not improve from 0.44828
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 229ms/step - accuracy: 0.3175 - loss: 0.5230 - val_accuracy: 0.4196 - val_loss: 0.6402
# Epoch 4/200
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 4s 173ms/step - accuracy: 0.3333 - loss: 0.4887
# Epoch 4: val_accuracy did not improve from 0.44828
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3333 - loss: 0.4887 - val_accuracy: 0.4483 - val_loss: 0.6408
# Epoch 5/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - accuracy: 0.3249 - loss: 0.5132
# Epoch 5: val_accuracy did not improve from 0.44828
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 227ms/step - accuracy: 0.3255 - loss: 0.5131 - val_accuracy: 0.4196 - val_loss: 0.6269
# Epoch 6/200
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 4s 175ms/step - accuracy: 0.3333 - loss: 0.4909
# Epoch 6: val_accuracy did not improve from 0.44828
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3333 - loss: 0.4909 - val_accuracy: 0.4483 - val_loss: 0.6273
# Epoch 7/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - accuracy: 0.3927 - loss: 0.4919
# Epoch 7: val_accuracy did not improve from 0.44828
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 226ms/step - accuracy: 0.3921 - loss: 0.4919 - val_accuracy: 0.4196 - val_loss: 0.6018
# Epoch 8/200
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 4s 170ms/step - accuracy: 0.2917 - loss: 0.5046
# Epoch 8: val_accuracy did not improve from 0.44828
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2917 - loss: 0.5046 - val_accuracy: 0.4483 - val_loss: 0.6028
# Epoch 9/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.3681 - loss: 0.4911
# Epoch 9: val_accuracy did not improve from 0.44828
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 223ms/step - accuracy: 0.3688 - loss: 0.4909 - val_accuracy: 0.4196 - val_loss: 0.5929
# Epoch 10/200
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 4s 176ms/step - accuracy: 0.3750 - loss: 0.4748
# Epoch 10: val_accuracy did not improve from 0.44828
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3750 - loss: 0.4748 - val_accuracy: 0.4483 - val_loss: 0.5951
# Epoch 11/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.3804 - loss: 0.4790
# Epoch 11: val_accuracy did not improve from 0.44828
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 223ms/step - accuracy: 0.3805 - loss: 0.4789 - val_accuracy: 0.4196 - val_loss: 0.5824
# Epoch 12/200
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 4s 183ms/step - accuracy: 0.3750 - loss: 0.4637
# Epoch 12: val_accuracy did not improve from 0.44828
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3750 - loss: 0.4637 - val_accuracy: 0.4483 - val_loss: 0.5831
# Epoch 13/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - accuracy: 0.3754 - loss: 0.4525
# Epoch 13: val_accuracy did not improve from 0.44828
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 233ms/step - accuracy: 0.3758 - loss: 0.4523 - val_accuracy: 0.4196 - val_loss: 0.5590
# Epoch 14/200
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - accuracy: 0.3750 - loss: 0.4430
# Epoch 14: val_accuracy did not improve from 0.44828
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3750 - loss: 0.4430 - val_accuracy: 0.4483 - val_loss: 0.5608
# Epoch 15/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - accuracy: 0.3976 - loss: 0.4393
# Epoch 15: val_accuracy improved from 0.44828 to 0.49554, saving model to ./base_model.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 230ms/step - accuracy: 0.3979 - loss: 0.4393 - val_accuracy: 0.4955 - val_loss: 0.5448
# Epoch 16/200
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - accuracy: 0.2917 - loss: 0.4668
# Epoch 16: val_accuracy did not improve from 0.49554
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2917 - loss: 0.4668 - val_accuracy: 0.4483 - val_loss: 0.5484
# Epoch 17/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - accuracy: 0.4411 - loss: 0.4109
# Epoch 17: val_accuracy did not improve from 0.49554
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 236ms/step - accuracy: 0.4413 - loss: 0.4111 - val_accuracy: 0.4375 - val_loss: 0.5527
# Epoch 18/200
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 4s 163ms/step - accuracy: 0.4583 - loss: 0.3974
# Epoch 18: val_accuracy did not improve from 0.49554
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4583 - loss: 0.3974 - val_accuracy: 0.3793 - val_loss: 0.5485
# Epoch 19/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - accuracy: 0.4402 - loss: 0.4224
# Epoch 19: val_accuracy did not improve from 0.49554
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 230ms/step - accuracy: 0
200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.7734 - loss: 0.2158
# Epoch 117: val_accuracy did not improve from 0.80804
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 223ms/step - accuracy: 0.7739 - loss: 0.2155 - val_accuracy: 0.7500 - val_loss: 0.2150
# Epoch 118/200
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 3s 151ms/step - accuracy: 0.8750 - loss: 0.2055
# Epoch 118: val_accuracy did not improve from 0.80804
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8750 - loss: 0.2055 - val_accuracy: 0.6552 - val_loss: 0.2736
# Epoch 119/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.7880 - loss: 0.1968
# Epoch 119: val_accuracy did not improve from 0.80804
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 218ms/step - accuracy: 0.7881 - loss: 0.1969 - val_accuracy: 0.7545 - val_loss: 0.2160
# Epoch 120/200
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.7500 - loss: 0.1588
# Epoch 120: val_accuracy did not improve from 0.80804
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7500 - loss: 0.1588 - val_accuracy: 0.7586 - val_loss: 0.2554
# Epoch 121/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - accuracy: 0.7806 - loss: 0.2197
# Epoch 121: val_accuracy improved from 0.80804 to 0.83929, saving model to ./base_model.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 225ms/step - accuracy: 0.7808 - loss: 0.2196 - val_accuracy: 0.8393 - val_loss: 0.2009
# Epoch 122/200
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - accuracy: 0.7500 - loss: 0.2039
# Epoch 122: val_accuracy did not improve from 0.83929
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7500 - loss: 0.2039 - val_accuracy: 0.6552 - val_loss: 0.2631
# Epoch 123/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - accuracy: 0.8204 - loss: 0.1799
# Epoch 123: val_accuracy did not improve from 0.83929
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 227ms/step - accuracy: 0.8205 - loss: 0.1798 - val_accuracy: 0.8125 - val_loss: 0.1790
# Epoch 124/200
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 3s 153ms/step - accuracy: 0.7500 - loss: 0.2406
# Epoch 124: val_accuracy did not improve from 0.83929
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7500 - loss: 0.2406 - val_accuracy: 0.6552 - val_loss: 0.2742
# Epoch 125/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - accuracy: 0.8087 - loss: 0.1987
# Epoch 125: val_accuracy did not improve from 0.83929
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 227ms/step - accuracy: 0.8078 - loss: 0.1992 - val_accuracy: 0.7500 - val_loss: 0.2263
# Epoch 126/200
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 3s 142ms/step - accuracy: 0.8750 - loss: 0.1885
# Epoch 126: val_accuracy did not improve from 0.83929
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8750 - loss: 0.1885 - val_accuracy: 0.6552 - val_loss: 0.2577
# Epoch 127/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.8016 - loss: 0.1885
# Epoch 127: val_accuracy did not improve from 0.83929
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 222ms/step - accuracy: 0.8018 - loss: 0.1885 - val_accuracy: 0.7500 - val_loss: 0.2100
# Epoch 128/200
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 3s 141ms/step - accuracy: 0.7083 - loss: 0.2569
# Epoch 128: val_accuracy did not improve from 0.83929
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7083 - loss: 0.2569 - val_accuracy: 0.6552 - val_loss: 0.2866
# Epoch 129/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - accuracy: 0.8295 - loss: 0.1735
# Epoch 129: val_accuracy improved from 0.83929 to 0.84821, saving model to ./base_model.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 229ms/step - accuracy: 0.8294 - loss: 0.1739 - val_accuracy: 0.8482 - val_loss: 0.1806
# Epoch 130/200
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 3s 152ms/step - accuracy: 0.7917 - loss: 0.1854
# Epoch 130: val_accuracy did not improve from 0.84821
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7917 - loss: 0.1854 - val_accuracy: 0.6552 - val_loss: 0.2707
# Epoch 131/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - accuracy: 0.7963 - loss: 0.2001
# Epoch 131: val_accuracy did not improve from 0.84821
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 228ms/step - accuracy: 0.7966 - loss: 0.1999 - val_accuracy: 0.7902 - val_loss: 0.1984
# Epoch 132/200
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 3s 153ms/step - accuracy: 0.7917 - loss: 0.1664
# Epoch 132: val_accuracy did not improve from 0.84821
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7917 - loss: 0.1664 - val_accuracy: 0.6207 - val_loss: 0.2731
# Epoch 133/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - accuracy: 0.7697 - loss: 0.2118
# Epoch 133: val_accuracy did not improve from 0.84821
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 228ms/step - accuracy: 0.7700 - loss: 0.2114 - val_accuracy: 0.7768 - val_loss: 0.2522
# Epoch 134/200
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 3s 138ms/step - accuracy: 0.7917 - loss: 0.2228
# Epoch 134: val_accuracy did not improve from 0.84821
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7917 - loss: 0.2228 - val_accuracy: 0.5862 - val_loss: 0.3247
# Epoch 135/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - accuracy: 0.8206 - loss: 0.1749
# Epoch 135: val_accuracy improved from 0.84821 to 0.85714, saving model to ./base_model.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 227ms/step - accuracy: 0.8206 - loss: 0.1750 - val_accuracy: 0.8571 - val_loss: 0.1748
# Epoch 136/200
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 3s 142ms/step - accuracy: 0
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8333 - loss: 0.1694 - val_accuracy: 0.6552 - val_loss: 0.2420
# Epoch 181/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - accuracy: 0.8992 - loss: 0.1171
# Epoch 181: val_accuracy did not improve from 0.87054
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 228ms/step - accuracy: 0.8982 - loss: 0.1181 - val_accuracy: 0.8304 - val_loss: 0.1705
# Epoch 182/200
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - accuracy: 0.9583 - loss: 0.1233
# Epoch 182: val_accuracy did not improve from 0.87054
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9583 - loss: 0.1233 - val_accuracy: 0.7241 - val_loss: 0.2582
# Epoch 183/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - accuracy: 0.8403 - loss: 0.1651
# Epoch 183: val_accuracy improved from 0.87054 to 0.87500, saving model to ./base_model.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 227ms/step - accuracy: 0.8406 - loss: 0.1650 - val_accuracy: 0.8750 - val_loss: 0.1408
# Epoch 184/200
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - accuracy: 0.9167 - loss: 0.1247
# Epoch 184: val_accuracy did not improve from 0.87500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9167 - loss: 0.1247 - val_accuracy: 0.7586 - val_loss: 0.2257
# Epoch 185/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - accuracy: 0.9026 - loss: 0.1216
# Epoch 185: val_accuracy did not improve from 0.87500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 229ms/step - accuracy: 0.9023 - loss: 0.1217 - val_accuracy: 0.8616 - val_loss: 0.1449
# Epoch 186/200
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 3s 153ms/step - accuracy: 0.7500 - loss: 0.3084
# Epoch 186: val_accuracy did not improve from 0.87500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7500 - loss: 0.3084 - val_accuracy: 0.6897 - val_loss: 0.2557
# Epoch 187/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.8764 - loss: 0.1273
# Epoch 187: val_accuracy did not improve from 0.87500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 224ms/step - accuracy: 0.8767 - loss: 0.1271 - val_accuracy: 0.8438 - val_loss: 0.1624
# Epoch 188/200
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - accuracy: 0.9167 - loss: 0.0924
# Epoch 188: val_accuracy did not improve from 0.87500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9167 - loss: 0.0924 - val_accuracy: 0.7931 - val_loss: 0.2088
# Epoch 189/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - accuracy: 0.8779 - loss: 0.1449
# Epoch 189: val_accuracy did not improve from 0.87500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 229ms/step - accuracy: 0.8776 - loss: 0.1447 - val_accuracy: 0.8214 - val_loss: 0.1843
# Epoch 190/200
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.7917 - loss: 0.2360
# Epoch 190: val_accuracy did not improve from 0.87500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7917 - loss: 0.2360 - val_accuracy: 0.6897 - val_loss: 0.2283
# Epoch 191/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - accuracy: 0.8932 - loss: 0.1342
# Epoch 191: val_accuracy did not improve from 0.87500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 226ms/step - accuracy: 0.8924 - loss: 0.1346 - val_accuracy: 0.8304 - val_loss: 0.1647
# Epoch 192/200
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 3s 151ms/step - accuracy: 0.8750 - loss: 0.2225
# Epoch 192: val_accuracy did not improve from 0.87500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8750 - loss: 0.2225 - val_accuracy: 0.7586 - val_loss: 0.2197
# Epoch 193/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - accuracy: 0.8889 - loss: 0.1289
# Epoch 193: val_accuracy did not improve from 0.87500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 224ms/step - accuracy: 0.8892 - loss: 0.1285 - val_accuracy: 0.8438 - val_loss: 0.1610
# Epoch 194/200
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 0.9167 - loss: 0.1527
# Epoch 194: val_accuracy did not improve from 0.87500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9167 - loss: 0.1527 - val_accuracy: 0.8621 - val_loss: 0.1671
# Epoch 195/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - accuracy: 0.8988 - loss: 0.1143
# Epoch 195: val_accuracy did not improve from 0.87500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 227ms/step - accuracy: 0.8987 - loss: 0.1146 - val_accuracy: 0.7857 - val_loss: 0.1924
# Epoch 196/200
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 3s 142ms/step - accuracy: 0.8750 - loss: 0.1182
# Epoch 196: val_accuracy did not improve from 0.87500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8750 - loss: 0.1182 - val_accuracy: 0.8276 - val_loss: 0.1846
# Epoch 197/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - accuracy: 0.8908 - loss: 0.1174
# Epoch 197: val_accuracy did not improve from 0.87500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 228ms/step - accuracy: 0.8905 - loss: 0.1175 - val_accuracy: 0.8616 - val_loss: 0.1531
# Epoch 198/200
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 3s 150ms/step - accuracy: 0.9167 - loss: 0.1773
# Epoch 198: val_accuracy did not improve from 0.87500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9167 - loss: 0.1773 - val_accuracy: 0.8276 - val_loss: 0.1763
# Epoch 199/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.8800 - loss: 0.1293
# Epoch 199: val_accuracy improved from 0.87500 to 0.88393, saving model to ./base_model.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 225ms/step - accuracy: 0.8800 - loss: 0.1294 - val_accuracy: 0.8839 - val_loss: 0.1510
# Epoch 200/200
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - accuracy: 1.0000 - loss: 0.0679
# Epoch 200: val_accuracy did not improve from 0.88393
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0679 - val_accuracy: 0.8276 - val_loss: 0.1741

# %%
show_final_history(history)
model.save("model.h5")
print("Weights Saved")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Weights Saved

# %%
test_pred = model.predict(test_images)
test_pred = np.argmax(test_pred,axis=1)
test_actual = np.argmax(test_labels,axis=1)

rnd_idx = random.sample(range(0,100),5)

class_labels = {i:class_name for (class_name,i) in class_name_labels.items()}

for i,idx in enumerate(rnd_idx):
    plt.imshow(test_images[idx])
    plt.title("Actual: {}\nPredicted: {}".format(class_labels[test_actual[idx]],class_labels[test_pred[idx]]))
    plt.grid(None)
    plt.show()
    pass
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
import numpy as np

# Load the pre-trained model
model = load_model('model.h5')

# Path to the image file
image_path = "data_week1/user_test/tea0001.png"

# Load and preprocess the image
img = image.load_img(image_path, target_size=(96, 96))
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)  # Convert single image to batch of size 1
img_array = img_array / 255.0  # Assuming your model was trained with inputs normalized to [0, 1]
print(img_array)
# Make predictions
predictions = model.predict(img_array)

# Print or use predictions as needed
print(predictions)
# Assuming predictions are probabilities (output of softmax), convert to class labels
predicted_class_index = np.argmax(predictions, axis=-1)
# Here, you might have a list or dictionary that maps index to class labels
class_labels = ["MILK","NUTS","OIL","SODA","TEA"]  # Replace with your actual class labels
class_name_labels = {class_name:i for i,class_name in enumerate(class_labels)}
print(class_name_labels)
predicted_class_label = class_labels[predicted_class_index[0]]

# Print or use predicted class label as needed
print("Predicted class:", predicted_class_label)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [[[[0.25490198 0.20392157 0.19215687]
#    [0.27450982 0.20784314 0.20784314]
#    [0.25882354 0.20784314 0.2       ]
#    ...
#    [0.09411765 0.07058824 0.0627451 ]
#    [0.09411765 0.07058824 0.07058824]
#    [0.09803922 0.07450981 0.07450981]]
#
#   [[0.26666668 0.21568628 0.19215687]
#    [0.2627451  0.21568628 0.19607843]
#    [0.2509804  0.20392157 0.18431373]
#    ...
#    [0.09803922 0.07843138 0.06666667]
#    [0.09803922 0.08235294 0.07450981]
#    [0.10980392 0.08627451 0.08627451]]
#
#   [[0.27058825 0.21176471 0.18431373]
#    [0.26666668 0.20392157 0.19607843]
#    [0.25882354 0.20392157 0.18431373]
#    ...
#    [0.10588235 0.08627451 0.07450981]
#    [0.09803922 0.07843138 0.07058824]
#    [0.10588235 0.08235294 0.07450981]]
#
#   ...
#
#   [[0.95686275 0.9529412  0.94509804]
#    [0.9607843  0.95686275 0.9490196 ]
#    [0.9607843  0.95686275 0.9490196 ]
#    ...
#    [0.9019608  0.9098039  0.9098039 ]
#    [0.8980392  0.9019608  0.90588236]
#    [0.8980392  0.90588236 0.9019608 ]]
#
#   [[0.9490196  0.93333334 0.92941177]
#    [0.9607843  0.95686275 0.9529412 ]
#    [0.9607843  0.95686275 0.9490196 ]
#    ...
#    [0.89411765 0.9019608  0.8980392 ]
#    [0.8980392  0.8980392  0.9019608 ]
#    [0.89411765 0.8980392  0.8980392 ]]
#
#   [[0.53333336 0.50980395 0.5254902 ]
#    [0.9019608  0.8784314  0.88235295]
#    [0.9529412  0.94509804 0.9411765 ]
#    ...
#    [0.8901961  0.8980392  0.89411765]
#    [0.8901961  0.89411765 0.89411765]
#    [0.8901961  0.8980392  0.89411765]]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# [[9.8760557e-01 1.5174677e-03 6.0316152e-04 8.8831742e-04 9.3856333e-03]]
# {'MILK': 0, 'NUTS': 1, 'OIL': 2, 'SODA': 3, 'TEA': 4}
# Predicted class: MILK
