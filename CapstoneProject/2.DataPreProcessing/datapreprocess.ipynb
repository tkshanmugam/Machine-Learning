# %%
import pandas as pd
import numpy as np

# %%
# Load the dataset (assuming it's in a CSV file)
data = pd.read_csv('../1.DataCollection/onlinefoods.csv')

# %%
data
# Out:
#      Age  Gender Marital Status Occupation  Monthly Income  \
# 0     20  Female         Single    Student       No Income
# 1     24  Female         Single    Student  Below Rs.10000
# 2     22    Male         Single    Student  Below Rs.10000
# 3     22  Female         Single    Student       No Income
# 4     22    Male         Single    Student  Below Rs.10000
# ..   ...     ...            ...        ...             ...
# 383   23  Female         Single    Student       No Income
# 384   23  Female         Single    Student       No Income
# 385   22  Female         Single    Student       No Income
# 386   23    Male         Single    Student  Below Rs.10000
# 387   23    Male         Single    Student       No Income
#
#     Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0                Post Graduate            4   12.9766    77.5993    560001
# 1                     Graduate            3   12.9770    77.5773    560009
# 2                Post Graduate            3   12.9551    77.6593    560017
# 3                     Graduate            6   12.9473    77.5616    560019
# 4                Post Graduate            4   12.9850    77.5533    560010
# ..                         ...          ...       ...        ...       ...
# 383              Post Graduate            2   12.9766    77.5993    560001
# 384              Post Graduate            4   12.9854    77.7081    560048
# 385              Post Graduate            5   12.9850    77.5533    560010
# 386              Post Graduate            2   12.9770    77.5773    560009
# 387              Post Graduate            5   12.8988    77.5764    560078
#
#     Output   Feedback Unnamed: 12
# 0      Yes   Positive         Yes
# 1      Yes   Positive         Yes
# 2      Yes  Negative          Yes
# 3      Yes   Positive         Yes
# 4      Yes   Positive         Yes
# ..     ...        ...         ...
# 383    Yes   Positive         Yes
# 384    Yes   Positive         Yes
# 385    Yes   Positive         Yes
# 386    Yes   Positive         Yes
# 387    Yes   Positive         Yes
#
# [388 rows x 13 columns]

# %%
#Identify Missing Values
data.isnull().sum()
# Out:
# Age                           0
# Gender                        0
# Marital Status                0
# Occupation                    0
# Monthly Income                0
# Educational Qualifications    0
# Family size                   0
# latitude                      0
# longitude                     0
# Pin code                      0
# Output                        0
# Feedback                      0
# Unnamed: 12                   0
# dtype: int64

# %%
def quanQual(dataset):
    quan=[]
    qual=[]
    for columnName in dataset.columns:
    #print(columnName)
        if(dataset[columnName].dtypes=='O'):
        #print("qual")
            qual.append(columnName)
        else:
        #print("quan")
             quan.append(columnName)
    return quan,qual

# %%
quan,qual=quanQual(data)

# %%
quan
# Out:
# ['Age', 'Family size', 'latitude', 'longitude', 'Pin code']

# %%
qual
# Out:
# [' education', ' self_employed', ' loan_status']

# %%
data[quan]
# Out:
#      Age  Family size  latitude  longitude  Pin code
# 0     20            4   12.9766    77.5993    560001
# 1     24            3   12.9770    77.5773    560009
# 2     22            3   12.9551    77.6593    560017
# 3     22            6   12.9473    77.5616    560019
# 4     22            4   12.9850    77.5533    560010
# ..   ...          ...       ...        ...       ...
# 383   23            2   12.9766    77.5993    560001
# 384   23            4   12.9854    77.7081    560048
# 385   22            5   12.9850    77.5533    560010
# 386   23            2   12.9770    77.5773    560009
# 387   23            5   12.8988    77.5764    560078
#
# [388 rows x 5 columns]

# %%
data.isna().sum()
# Out:
# Age                           0
# Gender                        0
# Marital Status                0
# Occupation                    0
# Monthly Income                0
# Educational Qualifications    0
# Family size                   0
# latitude                      0
# longitude                     0
# Pin code                      0
# Output                        0
# Feedback                      0
# Unnamed: 12                   0
# dtype: int64

# %%
def detect_outliers_iqr(data):
    # Calculate the first quartile (Q1) and third quartile (Q3)
    Q1 = np.percentile(data, 25)
    Q3 = np.percentile(data, 75)
    # Calculate the interquartile range (IQR)
    IQR = Q3 - Q1
    # Define the lower and upper bounds for outliers detection
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    # Find outliers
    outliers = [x for x in data if x < lower_bound or x > upper_bound]
    return outliers

# %%
for colunName in quan:
    outliers_iqr = detect_outliers_iqr(data[colunName])
    print("Outliers detected using IQR method :",colunName,  outliers_iqr)
# Out:
# Outliers detected using IQR method : Age [32, 31, 32, 18, 31, 32, 32, 32, 33, 32, 32, 32, 31, 31, 32, 31, 32, 32, 32, 31, 32, 32, 32, 32, 31, 31]
# Outliers detected using IQR method : Family size []
# Outliers detected using IQR method : latitude [13.102, 13.102]
# Outliers detected using IQR method : longitude [77.75, 77.75, 77.75, 77.75, 77.75, 77.75, 77.75, 77.75, 77.7582, 77.7582, 77.7582, 77.7582]
# Outliers detected using IQR method : Pin code []

# %%
csv=data.to_csv("preprocessed_online_food_dataset.csv",index=False)

# %%
csv
