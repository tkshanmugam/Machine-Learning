# %%
import pandas as pd
import numpy as np

# %%
# Load the dataset (assuming it's in a CSV file)
data = pd.read_csv('../1.DataCollection/loan_approval_dataset.csv')

# %%
data
# Out:
#       loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0           1                  2       Graduate             No        9600000
# 1           2                  0   Not Graduate            Yes        4100000
# 2           3                  3       Graduate             No        9100000
# 3           4                  3       Graduate             No        8200000
# 4           5                  5   Not Graduate            Yes        9800000
# ...       ...                ...            ...            ...            ...
# 4264     4265                  5       Graduate            Yes        1000000
# 4265     4266                  0   Not Graduate            Yes        3300000
# 4266     4267                  2   Not Graduate             No        6500000
# 4267     4268                  1   Not Graduate             No        4100000
# 4268     4269                  1       Graduate             No        9200000
#
# ...

# %%
#Identify Missing Values
data.isnull().sum()
# Out:
# loan_id                      0
#  no_of_dependents            0
#  education                   0
#  self_employed               0
#  income_annum                0
#  loan_amount                 0
#  loan_term                   0
#  cibil_score                 0
#  residential_assets_value    0
#  commercial_assets_value     0
#  luxury_assets_value         0
#  bank_asset_value            0
#  loan_status                 0
# dtype: int64

# %%
def quanQual(dataset):
    quan=[]
    qual=[]
    for columnName in dataset.columns:
    #print(columnName)
        if(dataset[columnName].dtypes=='O'):
        #print("qual")
            qual.append(columnName)
        else:
        #print("quan")
             quan.append(columnName)
    return quan,qual

# %%
quan,qual=quanQual(data)

# %%
quan
# Out:
# ['loan_id',
#  ' no_of_dependents',
#  ' income_annum',
#  ' loan_amount',
#  ' loan_term',
#  ' cibil_score',
#  ' residential_assets_value',
#  ' commercial_assets_value',
#  ' luxury_assets_value',
#  ' bank_asset_value']

# %%
qual
# Out:
# [' education', ' self_employed', ' loan_status']

# %%
data[quan]
# Out:
#       loan_id   no_of_dependents   income_annum   loan_amount   loan_term  \
# 0           1                  2        9600000      29900000          12
# 1           2                  0        4100000      12200000           8
# 2           3                  3        9100000      29700000          20
# 3           4                  3        8200000      30700000           8
# 4           5                  5        9800000      24200000          20
# ...       ...                ...            ...           ...         ...
# 4264     4265                  5        1000000       2300000          12
# 4265     4266                  0        3300000      11300000          20
# 4266     4267                  2        6500000      23900000          18
# 4267     4268                  1        4100000      12800000           8
# 4268     4269                  1        9200000      29700000          10
#
#        cibil_score   residential_assets_value   commercial_assets_value  \
# ...

# %%
data.isna().sum()
# Out:
# loan_id                      0
#  no_of_dependents            0
#  education                   0
#  self_employed               0
#  income_annum                0
#  loan_amount                 0
#  loan_term                   0
#  cibil_score                 0
#  residential_assets_value    0
#  commercial_assets_value     0
#  luxury_assets_value         0
#  bank_asset_value            0
#  loan_status                 0
# dtype: int64

# %%
def detect_outliers_iqr(data):
    # Calculate the first quartile (Q1) and third quartile (Q3)
    Q1 = np.percentile(data, 25)
    Q3 = np.percentile(data, 75)
    # Calculate the interquartile range (IQR)
    IQR = Q3 - Q1
    # Define the lower and upper bounds for outliers detection
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    # Find outliers
    outliers = [x for x in data if x < lower_bound or x > upper_bound]
    return outliers

# %%
for colunName in quan:
    outliers_iqr = detect_outliers_iqr(data[colunName])
    print("Outliers detected using IQR method :",colunName,  outliers_iqr)
# Out:
# Outliers detected using IQR method : loan_id []
# Outliers detected using IQR method :  no_of_dependents []
# Outliers detected using IQR method :  income_annum []
# Outliers detected using IQR method :  loan_amount []
# Outliers detected using IQR method :  loan_term []
# Outliers detected using IQR method :  cibil_score []
# Outliers detected using IQR method :  residential_assets_value [25500000, 25900000, 26800000, 25500000, 25600000, 25400000, 28300000, 26300000, 27600000, 28700000, 25300000, 25800000, 25500000, 25300000, 28200000, 25200000, 25800000, 25700000, 25500000, 27000000, 28500000, 26300000, 28400000, 27000000, 25900000, 28500000, 26600000, 26200000, 28000000, 25800000, 25500000, 26900000, 25200000, 27600000, 25300000, 26100000, 29100000, 25400000, 28200000, 25100000, 25600000, 25400000, 26100000, 27500000, 25000000, 25500000, 25400000, 26200000, 25100000, 27400000, 27300000, 26200000]
# ...

# %%
csv=data.to_csv("preprocessed_loan_approval_dataset.csv",index=False)

# %%
csv
